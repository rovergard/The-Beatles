# %% [markdown]
# ### Part 2
# Perform Data Quality Analysis on Beatles data collected in data collection phase

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
df = pd.read_pickle('BeatlesSongsMerged.pkl')
df.columns
# Out:
# Index(['song', 'core_catalogue_releases', 'songwriters', 'lead_vocals', 'year',
#        'SongKey', 'first_release_date', 'max_key', 'mode', 'avg_danceability',
#        'avg_energy', 'avg_loudness', 'avg_speechiness', 'avg_acousticness',
#        'avg_instrumentalness', 'avg_liveness', 'avg_valence', 'avg_tempo',
#        'avg_duration_ms', 'avg_time_signature', 'Song_y', 'lyrics',
#        'avg_popularity', 'BB_name', 'BB_artist', 'BB_debut_date',
#        'BB_peak_position', 'BB_peak_date', 'BB_weeks_on_chart',
#        'RollingStonePosition', 'Top20_x', 'Next30_x', 'Bottom20_x',
#        'RobSegment', 'Top20_y', 'Next30_y', 'Bottom20_y', 'LauraSegment',
#        'Top20_x', 'Next30_x', 'Bottom20_x', 'EmilySegment', 'Top20_y',
#        'Next30_y', 'Bottom20_y', 'OliviaSegment', 'Top20_x', 'Next30_x',
#        'Bottom20_x', 'BrianSegment', 'Top20_y', 'Next30_y', 'Bottom20_y',
#        'JackieSegment', 'Canonical_album', 'Year_y', 'first_vocalist',
#        'Paul_Song', 'John_Song', 'George_Song', 'Ringo_Song', 'cover', 'Era'],
#       dtype='object')

# %% [markdown]
# ## Do some basic data quality scans

# %%
# Display the first few rows of the DataFrame
##print(df.head())
print(df.head().to_string())
# Out:
#                   song core_catalogue_releases                     songwriters              lead_vocals  year            SongKey first_release_date  max_key  mode  avg_danceability  avg_energy  avg_loudness  avg_speechiness  avg_acousticness  avg_instrumentalness  avg_liveness  avg_valence   avg_tempo  avg_duration_ms  avg_time_signature               Song_y                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      lyrics  avg_popularity        BB_name    BB_artist BB_debut_date  BB_peak_position BB_peak_date  BB_weeks_on_chart  RollingStonePosition  Top20_x  Next30_x  Bottom20_x  RobSegment  Top20_y  Next30_y  Bottom20_y  LauraSegment  Top20_x  Next30_x  Bottom20_x  EmilySegment  Top20_y  Next30_y  Bottom20_y  OliviaSegment  Top20_x  Next30_x  Bottom20_x  BrianSegment  Top20_y  Next30_y  Bottom20_y  JackieSegment   Canonical_album   Year_y first_vocalist  Paul_Song  John_Song  George_Song  Ringo_Song  cover                    Era
# 0  Across the Universe  Let It Be Past Masters                Lennon McCartney                   Lennon  1969  acrosstheuniverse         1970-05-08      2.0   1.0          0.347600       0.409      -10.6498         0.028000          0.518200              0.000022      0.239420     0.789400  140.437800    223713.600000            4.000000  Across the universe                                                                   Words are flowing out like endless rain into a paper cup, They slither while they pass, they slip away across the universe Pools of sorrow, waves of joy are drifting through my open mind, Possessing and caressing me. Jai guru de va om Nothing's gonna change my world, Nothing's gonna change my world.  Images of broken light which dance before me like a million eyes, That call me on and on across the universe, Thoughts meander like a restless wind inside a letter box they Tumble blindly as they make their way Across the universe Jai guru de va om Nothing's gonna change my world, Nothing's gonna change my world.  Sounds of laughter shades of earth are ringing Through my open views inviting and inciting me Limitless undying love which shines around me like a Million suns, it calls me on and on Across the universe Jai guru de va om Nothing's gonna change my world, Nothing's gonna change my world.           41.875            NaN          NaN           NaT              <NA>          NaT               <NA>                   NaN
.0      NaN       NaN         NaN           3.0      NaN       NaN         NaN           3.0      NaN       NaN         NaN            3.0      NaN       1.0         NaN           4.0      NaN       NaN         NaN            3.0  With The Beatles   1963.0      McCartney          1          0            0           0      0            Beatlemania
# 4     All Together Now        Yellow Submarine                Lennon McCartney  McCartney (with Lennon)  1969     alltogethernow         1969-01-17     11.0   1.0          0.596500       0.422       -8.6985         0.065400          0.094100              0.000000      0.456500     0.833500   96.091000    130760.000000            4.000000     All together now                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        One, two, three, four Can I have a little more? five, six, seven eight nine ten I love you.  A, B, C, D Can I bring my friend to tea? E, F, G H I J I love you.  Sail the ship, Jump the tree Skip the rope, Look at me  All together now....  Black, white, green, red Can I take my friend to bed? Pink, brown, yellow orange blue I love you  All together now....  Sail the ship, Jump the tree Skip the rope, Look at me  All together now....           46.000            NaN          NaN           NaT              <NA>          NaT               <NA>                   NaN      NaN       NaN         NaN         3.0      NaN       NaN         1.0           1.0      1.0       NaN         NaN           5.0      NaN       NaN         NaN            3.0      NaN       NaN         NaN           3.0      NaN       NaN         NaN            3.0  Yellow Submarine   1969.0      McCartney          1          0            0           0      0  Group of Solo Artists

# %%
# 1. Check for missing data
missing = df.isnull().sum()
print("Missing values:\n", missing)
# Out:
# Missing values:
#  song                         0
# core_catalogue_releases      0
# songwriters                  0
# lead_vocals                  0
# year                         0
# SongKey                      0
# first_release_date           0
# max_key                      9
# mode                         9
# avg_danceability             9
# avg_energy                   9
# avg_loudness                 9
# avg_speechiness              9
# avg_acousticness             9
# avg_instrumentalness         9
# avg_liveness                 9
# avg_valence                  9
# avg_tempo                    9
# avg_duration_ms              9
# avg_time_signature           9
# Song_y                      12
# lyrics                      12
# avg_popularity               4
# BB_name                    156
# BB_artist                  156
# BB_debut_date              156
# BB_peak_position           156
# BB_peak_date               156
# BB_weeks_on_chart          156
# RollingStonePosition       189
# Top20_x                    195
# Next30_x                   185
# Bottom20_x                 195
# RobSegment                   0
# Top20_y                    195
# Next30_y                   185
# Bottom20_y                 205
# LauraSegment                 0
# Top20_x                    195
# Next30_x                   185
# Bottom20_x                 195
# EmilySegment                 0
# Top20_y                    194
# Next30_y                   185
# Bottom20_y                 215
# OliviaSegment                0
# Top20_x                    195
# Next30_x                   185
# Bottom20_x                 195
# BrianSegment                 0
# Top20_y                    195
# Next30_y                   185
# Bottom20_y                 215
# JackieSegment                2
# Canonical_album             29
# Year_y                      29
# first_vocalist               0
# Paul_Song                    0
# John_Song                    0
# George_Song                  0
# Ringo_Song                   0
# cover                        0
# Era                          0
# dtype: int64

# %%
missing_avg_danceability = df[df['avg_danceability'].isnull()]
print(missing_avg_danceability)
# Out:
#                                                   song  \
# 16                                             Bad Boy
# 78                                    I Call Your Name
# 97                                            I'm Down
# 110                       Kansas City/Hey-Hey-Hey-Hey!
# 111  Komm, gib mir deine Hand  (German version of I...
# 147                                 Please Mr. Postman
# 168  Sie liebt dich  (German version of She Loves You)
# 202                                          Yes It Is
# 205              You Know My Name (Look Up the Number)
#
#                                core_catalogue_releases  \
# 16                                        Past Masters
# 78                                        Past Masters
# 97                      Past Masters (B-side of Help!)
# 110                                   Beatles for Sale
# 111                                       Past Masters
# 147                                   With the Beatles
# 168  Past Masters (B-side of Komm, gib mir deine Hand)
# 202            Past Masters (B-side of Ticket to Ride)
# 205                 Past Masters (B-side of Let It Be)
#
#                                            songwriters  \
# 16                                    Larry Williams †
# 78                                    Lennon McCartney
# 97                                    Lennon McCartney
# 110     Jerry Leiber Mike Stoller / Richard Penniman †
# 111        Lennon McCartney Jean Nicolas Heinz Hellmer
# 147  Georgia Dobbins William Garrett Brian Holland ...
# 168         Lennon McCartney Jean Nicolas Lee Montogue
# 202                                   Lennon McCartney
# 205                                   Lennon McCartney
#
#                               lead_vocals  year  \
# 16                                 Lennon  1965
# 78                                 Lennon  1964
# 97                              McCartney  1965
# 110                             McCartney  1964
# 111                      Lennon McCartney  1964
# 147                                Lennon  1963
# 168                      Lennon McCartney  1964
# 202  Lennon (with McCartney and Harrison)  1965
# 205                      Lennon McCartney  1970
#
#                                                SongKey first_release_date  \
# 16                                              badboy         1965-05-10
# 78                                       icallyourname         1964-06-19
# 97                                              imdown         1965-07-19
# 110                         kansascity/hey-hey-hey-hey         1965-10-11
# 111  kommgibmirdeinehandgermanversionofiwanttoholdy...         1964-01-29
# 147                                    pleasemrpostman         1963-12-09
# 168             sieliebtdichgermanversionofshelovesyou         1964-01-29
# 202                                            yesitis         1965-05-01
# 205                       youknowmynamelookupthenumber         1970-03-06
#
#      max_key  mode  avg_danceability  avg_energy  avg_loudness  \
# 16       NaN   NaN               NaN         NaN           NaN
# 78       NaN   NaN               NaN         NaN           NaN
# 97       NaN   NaN               NaN         NaN           NaN
# 110      NaN   NaN               NaN         NaN           NaN
# 111      NaN   NaN               NaN         NaN           NaN
# 147      NaN   NaN               NaN         NaN           NaN
# 168      NaN   NaN               NaN         NaN           NaN
# 202      NaN   NaN               NaN         NaN           NaN
# 205      NaN   NaN               NaN         NaN           NaN
#
#      avg_speechiness  avg_acousticness  avg_instrumentalness  avg_liveness  \
# 16               NaN               NaN                   NaN           NaN
# 78               NaN               NaN                   NaN           NaN
# 97               NaN               NaN                   NaN           NaN
# 110              NaN               NaN                   NaN           NaN
# 111              NaN               NaN                   NaN           NaN
# 147              NaN               NaN                   NaN           NaN
# 168              NaN               NaN                   NaN           NaN
# 202              NaN               NaN                   NaN           NaN
# 205              NaN               NaN                   NaN           NaN
#
#      avg_valence  avg_tempo  avg_duration_ms  avg_time_signature  \
# 16           NaN        NaN              NaN                 NaN
# 78           NaN        NaN              NaN                 NaN
# 97           NaN        NaN              NaN                 NaN
# 110          NaN        NaN              NaN                 NaN
# 111          NaN        NaN              NaN                 NaN
# 147          NaN        NaN              NaN                 NaN
# 168          NaN        NaN              NaN                 NaN
# 202          NaN        NaN              NaN                 NaN
# 205          NaN        NaN              NaN                 NaN
#
#                                     Song_y  \
# 16                                 Bad boy
# 78                        I call your name
# 97                                I'm down
# 110                                    NaN
# 111                                    NaN
# 147                                    NaN
# 168                                    NaN
# 202                              Yes it is
# 205  You know my name (look up the number)
#
#                                                 lyrics  avg_popularity  \
# 16   A bad little kid moved into my neighborhood He...       40.000000
# 78   I call your name but you're not there, was I t...       41.000000
# 97   You telling lies thinking I can't see You don'...       39.500000
# 110                                                NaN             NaN
# 111                                                NaN             NaN
# 147                                                NaN             NaN
# 168                                                NaN             NaN
# 202  If you wear red tonight, Remember what I said ...       33.666667
# 205  You know my name Look up the number You know m...       36.500000
#
#        BB_name    BB_artist BB_debut_date  BB_peak_position BB_peak_date  \
# 16         NaN          NaN           NaT              <NA>          NaT
# 78         NaN          NaN           NaT              <NA>          NaT
# 97         NaN          NaN           NaT              <NA>          NaT
# 110        NaN          NaN           NaT              <NA>          NaT
# 111        NaN          NaN           NaT              <NA>          NaT
# 147        NaN          NaN           NaT              <NA>          NaT
# 168        NaN          NaN           NaT              <NA>          NaT
# 202  Yes It Is  The Beatles    1965-05-01                46   1965-05-15
# 205        NaN          NaN           NaT              <NA>          NaT
#
#      BB_weeks_on_chart  RollingStonePosition  Top20_x  Next30_x  Bottom20_x  \
# 16                <NA>                   NaN      NaN       NaN         NaN
# 78                <NA>                   NaN      NaN       NaN         NaN
# 97                <NA>                   NaN      NaN       NaN         NaN
# 110               <NA>                   NaN      NaN       NaN         NaN
# 111               <NA>                   NaN      NaN       NaN         NaN
# 147               <NA>                   NaN      NaN       NaN         NaN
# 168               <NA>                   NaN      NaN       NaN         NaN
# 202                  4                   NaN      NaN       NaN         NaN
# 205               <NA>                   NaN      NaN       NaN         NaN
#
#      RobSegment  Top20_y  Next30_y  Bottom20_y  LauraSegment  Top20_x  \
# 16          3.0      NaN       NaN         NaN           3.0      NaN
# 78          3.0      NaN       NaN         NaN           3.0      NaN
# 97          3.0      NaN       NaN         NaN           3.0      NaN
# 110         3.0      NaN       NaN         NaN           3.0      NaN
# 111         3.0      NaN       NaN         NaN           3.0      NaN
# 147         3.0      NaN       NaN         NaN           3.0      NaN
# 168         3.0      NaN       NaN         NaN           3.0      NaN
# 202         3.0      NaN       NaN         NaN           3.0      NaN
# 205         3.0      NaN       NaN         NaN           3.0      NaN
#
#      Next30_x  Bottom20_x  EmilySegment  Top20_y  Next30_y  Bottom20_y  \
# 16        NaN         NaN           3.0      NaN       NaN         NaN
# 78        NaN         NaN           3.0      NaN       NaN         NaN
# 97        NaN         1.0           1.0      NaN       NaN         NaN
# 110       NaN         NaN           3.0      NaN       NaN         NaN
# 111       NaN         NaN           3.0      NaN       NaN         NaN
# 147       NaN         NaN           3.0      NaN       NaN         NaN
# 168       NaN         NaN           3.0      NaN       NaN         NaN
# 202       1.0         NaN           4.0      NaN       NaN         NaN
# 205       1.0         NaN           4.0      NaN       NaN         NaN
#
#      OliviaSegment  Top20_x  Next30_x  Bottom20_x  BrianSegment  Top20_y  \
# 16             3.0      NaN       NaN         NaN           3.0      NaN
# 78             3.0      NaN       1.0         NaN           4.0      NaN
# 97             3.0      NaN       NaN         NaN           3.0      NaN
# 110            3.0      NaN       NaN         NaN           3.0      NaN
# 111            3.0      NaN       NaN         1.0           1.0      NaN
# 147            3.0      NaN       NaN         NaN           3.0      NaN
# 168            3.0      NaN       NaN         1.0           1.0      NaN
# 202            3.0      NaN       NaN         NaN           3.0      NaN
# 205            3.0      NaN       NaN         1.0           1.0      NaN
#
#      Next30_y  Bottom20_y  JackieSegment   Canonical_album  Year_y  \
# 16        NaN         NaN            3.0               NaN     NaN
# 78        NaN         NaN            3.0               NaN     NaN
# 97        NaN         NaN            3.0               NaN     NaN
# 110       NaN         NaN            3.0  Beatles for Sale  1964.0
# 111       NaN         NaN            3.0               NaN     NaN
# 147       NaN         NaN            3.0  With The Beatles  1963.0
# 168       NaN         NaN            3.0               NaN     NaN
# 202       NaN         NaN            3.0               NaN     NaN
# 205       NaN         NaN            3.0               NaN     NaN
#
#     first_vocalist  Paul_Song  John_Song  George_Song  Ringo_Song  cover  \
# 16          Lennon          0          1            0           0      1
# 78          Lennon          0          1            0           0      0
# 97       McCartney          1          0            0           0      0
# 110      McCartney          1          0            0           0      1
# 111         Lennon          0          1            0           0      0
# 147         Lennon          0          1            0           0      1
# 168         Lennon          0          1            0           0      0
# 202         Lennon          0          1            0           0      0
# 205         Lennon          0          1            0           0      0
#
#                        Era
# 16             Beatlemania
# 78             Beatlemania
# 97             Beatlemania
# 110           Experimental
# 111            Beatlemania
# 147            Beatlemania
# 168            Beatlemania
# 202            Beatlemania
# 205  Group of Solo Artists

# %%
missing_lyrics = df[df['lyrics'].isnull()]
print(missing_lyrics)
# Out:
#                                                   song  \
# 36                                    Dizzy Miss Lizzy
# 50                                              Flying
# 98                    I'm Happy Just to Dance with You
# 110                       Kansas City/Hey-Hey-Hey-Hey!
# 111  Komm, gib mir deine Hand  (German version of I...
# 147                                 Please Mr. Postman
# 150                                    P.S. I Love You
# 153                                       Revolution 1
# 154                                       Revolution 9
# 168  Sie liebt dich  (German version of She Loves You)
# 178                                    There's a Place
# 180                                 Think for Yourself
#
#                                core_catalogue_releases  \
# 36                                               Help!
# 50                                Magical Mystery Tour
# 98                                  A Hard Day's Night
# 110                                   Beatles for Sale
# 111                                       Past Masters
# 147                                   With the Beatles
# 150                                   Please Please Me
# 153                          The Beatles (White Album)
# 154                          The Beatles (White Album)
# 168  Past Masters (B-side of Komm, gib mir deine Hand)
# 178                                   Please Please Me
# 180                                        Rubber Soul
#
#                                            songwriters       lead_vocals  \
# 36                                    Larry Williams †            Lennon
# 50                   Lennon McCartney Harrison Starkey      Instrumental
# 98                                    Lennon McCartney          Harrison
# 110     Jerry Leiber Mike Stoller / Richard Penniman †         McCartney
# 111        Lennon McCartney Jean Nicolas Heinz Hellmer  Lennon McCartney
# 147  Georgia Dobbins William Garrett Brian Holland ...            Lennon
# 150                                   Lennon McCartney         McCartney
# 153                                   Lennon McCartney            Lennon
# 154                                   Lennon McCartney     Sound Collage
# 168         Lennon McCartney Jean Nicolas Lee Montogue  Lennon McCartney
# 178                                   Lennon McCartney  Lennon McCartney
# 180                                           Harrison          Harrison
#
#      year                                            SongKey  \
# 36   1965                                     dizzymisslizzy
# 50   1967                                             flying
# 98   1964                          imhappyjusttodancewithyou
# 110  1964                         kansascity/hey-hey-hey-hey
# 111  1964  kommgibmirdeinehandgermanversionofiwanttoholdy...
# 147  1963                                    pleasemrpostman
# 150  1962                                         psiloveyou
# 153  1968                                        revolution1
# 154  1968                                        revolution9
# 168  1964             sieliebtdichgermanversionofshelovesyou
# 178  1963                                       theresaplace
# 180  1965                                   thinkforyourself
#
#     first_release_date  max_key  mode  avg_danceability  avg_energy  \
# 36          1965-08-06     11.0   1.0          0.449333    0.827000
# 50          1967-11-27      0.0   1.0          0.551000    0.395000
# 98          1964-07-10      6.0   0.0          0.658000    0.537000
# 110         1965-10-11      NaN   NaN               NaN         NaN
# 111         1964-01-29      NaN   NaN               NaN         NaN
# 147         1963-12-09      NaN   NaN               NaN         NaN
# 150         1963-03-22      2.0   1.0          0.592500    0.475500
# 153         1968-11-22      9.0   1.0          0.397333    0.625333
# 154         1968-11-22      9.0   0.0          0.200500    0.660500
# 168         1964-01-29      NaN   NaN               NaN         NaN
# 178         1963-03-22      4.0   1.0          0.484500    0.624500
# 180         1965-12-03      0.0   1.0          0.528500    0.579000
#
#      avg_loudness  avg_speechiness  avg_acousticness  avg_instrumentalness  \
# 36        -7.7070         0.047867          0.064867              0.001589
# 50       -14.7550         0.050100          0.368000              0.880000
# 98        -7.5350         0.030700          0.138000              0.000000
# 110           NaN              NaN               NaN                   NaN
# 111           NaN              NaN               NaN                   NaN
# 147           NaN              NaN               NaN                   NaN
# 150      -10.4810         0.030200          0.420000              0.000639
# 153       -9.9050         0.055300          0.108967              0.005912
# 154      -13.8445         0.355500          0.772000              0.104400
# 168           NaN              NaN               NaN                   NaN
# 178       -9.2705         0.029700          0.631000              0.000002
# 180       -8.6035         0.028200          0.014300              0.000000
#
#      avg_liveness  avg_valence   avg_tempo  avg_duration_ms  \
# 36       0.252967       0.8720  136.184000    186715.666667
# 50       0.093200       0.2610   92.929000    135520.000000
# 98       0.057200       0.8870  132.115000    116373.000000
# 110           NaN          NaN         NaN              NaN
# 111           NaN          NaN         NaN              NaN
# 147           NaN          NaN         NaN              NaN
# 150      0.156900       0.7530  136.546500    121846.500000
# 153      0.563667       0.5370   99.358667    380089.000000
# 154      0.803000       0.1100   86.691000    501433.000000
# 168           NaN          NaN         NaN              NaN
# 178      0.397500       0.8955  106.390000    109726.500000
# 180      0.072750       0.7975  130.491000    138580.000000
#
#      avg_time_signature Song_y lyrics  avg_popularity  \
# 36                  4.0    NaN    NaN       40.500000
# 50                  4.0    NaN    NaN       53.000000
# 98                  4.0    NaN    NaN       56.000000
# 110                 NaN    NaN    NaN             NaN
# 111                 NaN    NaN    NaN             NaN
# 147                 NaN    NaN    NaN             NaN
# 150                 4.0    NaN    NaN       39.500000
# 153                 4.0    NaN    NaN       38.666667
# 154                 4.0    NaN    NaN       40.000000
# 168                 NaN    NaN    NaN             NaN
# 178                 4.0    NaN    NaN       38.000000
# 180                 4.0    NaN    NaN       47.000000
#
#                               BB_name    BB_artist BB_debut_date  \
# 36                                NaN          NaN           NaT
# 50                                NaN          NaN           NaT
# 98   I'm Happy Just To Dance With You  The Beatles    1964-08-01
# 110                               NaN          NaN           NaT
# 111                               NaN          NaN           NaT
# 147                               NaN          NaN           NaT
# 150                   P.S. I Love You  The Beatles    1964-05-09
# 153                               NaN          NaN           NaT
# 154                               NaN          NaN           NaT
# 168                               NaN          NaN           NaT
# 178                   There's A Place  The Beatles    1964-04-11
# 180                               NaN          NaN           NaT
#
#      BB_peak_position BB_peak_date  BB_weeks_on_chart  RollingStonePosition  \
# 36               <NA>          NaT               <NA>                   NaN
# 50               <NA>          NaT               <NA>                   NaN
# 98                 95   1964-08-01                  1                   NaN
# 110              <NA>          NaT               <NA>                   NaN
# 111              <NA>          NaT               <NA>                   NaN
# 147              <NA>          NaT               <NA>                   NaN
# 150                10   1964-06-06                  8                   NaN
# 153              <NA>          NaT               <NA>                   NaN
# 154              <NA>          NaT               <NA>                   NaN
# 168              <NA>          NaT               <NA>                   NaN
# 178                74   1964-04-11                  1                   NaN
# 180              <NA>          NaT               <NA>                   NaN
#
#      Top20_x  Next30_x  Bottom20_x  RobSegment  Top20_y  Next30_y  Bottom20_y  \
# 36       NaN       NaN         NaN         3.0      NaN       NaN         1.0
# 50       NaN       NaN         NaN         3.0      NaN       NaN         NaN
# 98       NaN       NaN         NaN         3.0      NaN       NaN         NaN
# 110      NaN       NaN         NaN         3.0      NaN       NaN         NaN
# 111      NaN       NaN         NaN         3.0      NaN       NaN         NaN
# 147      NaN       NaN         NaN         3.0      NaN       NaN         NaN
# 150      NaN       NaN         NaN         3.0      NaN       NaN         NaN
# 153      NaN       NaN         NaN         3.0      NaN       NaN         NaN
# 154      NaN       NaN         1.0         1.0      NaN       NaN         NaN
# 168      NaN       NaN         NaN         3.0      NaN       NaN         NaN
# 178      NaN       NaN         NaN         3.0      NaN       NaN         NaN
# 180      NaN       NaN         NaN         3.0      NaN       NaN         NaN
#
#      LauraSegment  Top20_x  Next30_x  Bottom20_x  EmilySegment  Top20_y  \
# 36            1.0      NaN       NaN         1.0           1.0      NaN
# 50            3.0      NaN       NaN         NaN           3.0      NaN
# 98            3.0      NaN       NaN         NaN           3.0      NaN
# 110           3.0      NaN       NaN         NaN           3.0      NaN
# 111           3.0      NaN       NaN         NaN           3.0      NaN
# 147           3.0      NaN       NaN         NaN           3.0      NaN
# 150           3.0      NaN       1.0         NaN           4.0      NaN
# 153           3.0      NaN       NaN         NaN           3.0      NaN
# 154           3.0      NaN       NaN         NaN           3.0      NaN
# 168           3.0      NaN       NaN         NaN           3.0      NaN
# 178           3.0      NaN       NaN         NaN           3.0      NaN
# 180           3.0      NaN       NaN         NaN           3.0      NaN
#
#      Next30_y  Bottom20_y  OliviaSegment  Top20_x  Next30_x  Bottom20_x  \
# 36        NaN         NaN            3.0      NaN       NaN         NaN
# 50        NaN         NaN            3.0      NaN       NaN         NaN
# 98        NaN         NaN            3.0      NaN       NaN         NaN
# 110       NaN         NaN            3.0      NaN       NaN         NaN
# 111       NaN         NaN            3.0      NaN       NaN         1.0
# 147       NaN         NaN            3.0      NaN       NaN         NaN
# 150       NaN         NaN            3.0      NaN       NaN         NaN
# 153       NaN         NaN            3.0      NaN       NaN         NaN
# 154       NaN         NaN            3.0      NaN       NaN         1.0
# 168       NaN         NaN            3.0      NaN       NaN         1.0
# 178       NaN         NaN            3.0      NaN       1.0         NaN
# 180       NaN         NaN            3.0      NaN       NaN         NaN
#
#      BrianSegment  Top20_y  Next30_y  Bottom20_y  JackieSegment  \
# 36            3.0      NaN       NaN         NaN            3.0
# 50            3.0      NaN       NaN         NaN            3.0
# 98            3.0      NaN       NaN         NaN            3.0
# 110           3.0      NaN       NaN         NaN            3.0
# 111           1.0      NaN       NaN         NaN            3.0
# 147           3.0      NaN       NaN         NaN            3.0
# 150           3.0      NaN       NaN         NaN            3.0
# 153           3.0      NaN       NaN         NaN            3.0
# 154           1.0      NaN       NaN         NaN            3.0
# 168           1.0      NaN       NaN         NaN            3.0
# 178           4.0      NaN       NaN         NaN            3.0
# 180           3.0      NaN       NaN         NaN            3.0
#
#           Canonical_album  Year_y first_vocalist  Paul_Song  John_Song  \
# 36                  Help!  1965.0         Lennon          0          1
# 50   Magical Mystery Tour  1967.0   Instrumental          0          0
# 98      A Hard Days Night  1964.0       Harrison          0          0
# 110      Beatles for Sale  1964.0      McCartney          1          0
# 111                   NaN     NaN         Lennon          0          1
# 147      With The Beatles  1963.0         Lennon          0          1
# 150      Please Please Me  1963.0      McCartney          1          0
# 153           The Beatles  1968.0         Lennon          0          1
# 154           The Beatles  1968.0          Sound          0          0
# 168                   NaN     NaN         Lennon          0          1
# 178      Please Please Me  1963.0         Lennon          0          1
# 180           Rubber Soul  1965.0       Harrison          0          0
#
#      George_Song  Ringo_Song  cover           Era
# 36             0           0      1   Beatlemania
# 50             0           0      0  Experimental
# 98             1           0      0   Beatlemania
# 110            0           0      1  Experimental
# 111            0           0      0   Beatlemania
# 147            0           0      1   Beatlemania
# 150            0           0      0   Beatlemania
# 153            0           0      0  Experimental
# 154            0           0      0  Experimental
# 168            0           0      0   Beatlemania
# 178            0           0      0   Beatlemania
# 180            1           0      0  Experimental

# %%
missing_avg_popularity = df[df['avg_popularity'].isnull()]
print(missing_avg_popularity)
## these will be dropped along with the songs with missing danceability
# Out:
#                                                   song  \
# 110                       Kansas City/Hey-Hey-Hey-Hey!
# 111  Komm, gib mir deine Hand  (German version of I...
# 147                                 Please Mr. Postman
# 168  Sie liebt dich  (German version of She Loves You)
#
#                                core_catalogue_releases  \
# 110                                   Beatles for Sale
# 111                                       Past Masters
# 147                                   With the Beatles
# 168  Past Masters (B-side of Komm, gib mir deine Hand)
#
#                                            songwriters       lead_vocals  \
# 110     Jerry Leiber Mike Stoller / Richard Penniman †         McCartney
# 111        Lennon McCartney Jean Nicolas Heinz Hellmer  Lennon McCartney
# 147  Georgia Dobbins William Garrett Brian Holland ...            Lennon
# 168         Lennon McCartney Jean Nicolas Lee Montogue  Lennon McCartney
#
#      year                                            SongKey  \
# 110  1964                         kansascity/hey-hey-hey-hey
# 111  1964  kommgibmirdeinehandgermanversionofiwanttoholdy...
# 147  1963                                    pleasemrpostman
# 168  1964             sieliebtdichgermanversionofshelovesyou
#
#     first_release_date  max_key  mode  avg_danceability  avg_energy  \
# 110         1965-10-11      NaN   NaN               NaN         NaN
# 111         1964-01-29      NaN   NaN               NaN         NaN
# 147         1963-12-09      NaN   NaN               NaN         NaN
# 168         1964-01-29      NaN   NaN               NaN         NaN
#
#      avg_loudness  avg_speechiness  avg_acousticness  avg_instrumentalness  \
# 110           NaN              NaN               NaN                   NaN
# 111           NaN              NaN               NaN                   NaN
# 147           NaN              NaN               NaN                   NaN
# 168           NaN              NaN               NaN                   NaN
#
#      avg_liveness  avg_valence  avg_tempo  avg_duration_ms  \
# 110           NaN          NaN        NaN              NaN
# 111           NaN          NaN        NaN              NaN
# 147           NaN          NaN        NaN              NaN
# 168           NaN          NaN        NaN              NaN
#
#      avg_time_signature Song_y lyrics  avg_popularity BB_name BB_artist  \
# 110                 NaN    NaN    NaN             NaN     NaN       NaN
# 111                 NaN    NaN    NaN             NaN     NaN       NaN
# 147                 NaN    NaN    NaN             NaN     NaN       NaN
# 168                 NaN    NaN    NaN             NaN     NaN       NaN
#
#     BB_debut_date  BB_peak_position BB_peak_date  BB_weeks_on_chart  \
# 110           NaT              <NA>          NaT               <NA>
# 111           NaT              <NA>          NaT               <NA>
# 147           NaT              <NA>          NaT               <NA>
# 168           NaT              <NA>          NaT               <NA>
#
#      RollingStonePosition  Top20_x  Next30_x  Bottom20_x  RobSegment  Top20_y  \
# 110                   NaN      NaN       NaN         NaN         3.0      NaN
# 111                   NaN      NaN       NaN         NaN         3.0      NaN
# 147                   NaN      NaN       NaN         NaN         3.0      NaN
# 168                   NaN      NaN       NaN         NaN         3.0      NaN
#
#      Next30_y  Bottom20_y  LauraSegment  Top20_x  Next30_x  Bottom20_x  \
# 110       NaN         NaN           3.0      NaN       NaN         NaN
# 111       NaN         NaN           3.0      NaN       NaN         NaN
# 147       NaN         NaN           3.0      NaN       NaN         NaN
# 168       NaN         NaN           3.0      NaN       NaN         NaN
#
#      EmilySegment  Top20_y  Next30_y  Bottom20_y  OliviaSegment  Top20_x  \
# 110           3.0      NaN       NaN         NaN            3.0      NaN
# 111           3.0      NaN       NaN         NaN            3.0      NaN
# 147           3.0      NaN       NaN         NaN            3.0      NaN
# 168           3.0      NaN       NaN         NaN            3.0      NaN
#
#      Next30_x  Bottom20_x  BrianSegment  Top20_y  Next30_y  Bottom20_y  \
# 110       NaN         NaN           3.0      NaN       NaN         NaN
# 111       NaN         1.0           1.0      NaN       NaN         NaN
# 147       NaN         NaN           3.0      NaN       NaN         NaN
# 168       NaN         1.0           1.0      NaN       NaN         NaN
#
#      JackieSegment   Canonical_album  Year_y first_vocalist  Paul_Song  \
# 110            3.0  Beatles for Sale  1964.0      McCartney          1
# 111            3.0               NaN     NaN         Lennon          0
# 147            3.0  With The Beatles  1963.0         Lennon          0
# 168            3.0               NaN     NaN         Lennon          0
#
#      John_Song  George_Song  Ringo_Song  cover           Era
# 110          0            0           0      1  Experimental
# 111          1            0           0      0   Beatlemania
# 147          1            0           0      1   Beatlemania
# 168          1            0           0      0   Beatlemania

# %%
#drop rows where Spotify song metadata is missing. All of these songs are minor so it shouldn't affect the analysis and it's not worth hunting down a better solution
df = df.dropna(subset=['avg_danceability'])
df = df.dropna(subset=['lyrics'])

# %%
# 2. Check for duplicate rows
duplicates = df.duplicated().sum()
print("\nDuplicate rows: ", duplicates)
# Out:
# Duplicate rows:  0

# %%
# 3. Descriptive statistics for numeric columns
statistics = df.describe()
print("\nDescriptive Statistics:\n", statistics)
# Out:
# Descriptive Statistics:
#            max_key        mode  avg_danceability  avg_energy  avg_loudness  \
# count  198.000000  198.000000        198.000000  198.000000    198.000000
# mean     5.994949    0.919192          0.533346    0.549670     -9.991401
# std      3.371269    0.273231          0.125137    0.176141      2.185938
# min      0.000000    0.000000          0.245500    0.153575    -21.674000
# 25%      4.000000    1.000000          0.450196    0.426229    -11.214562
# 50%      7.000000    1.000000          0.530200    0.557250     -9.652250
# 75%      9.000000    1.000000          0.634417    0.692250     -8.573000
# max     11.000000    1.000000          0.806200    0.888000     -6.201000
#
#        avg_speechiness  avg_acousticness  avg_instrumentalness  avg_liveness  \
# count       198.000000        198.000000            198.000000    198.000000
# mean          0.050359          0.361892              0.056720      0.233173
# std           0.030674          0.253176              0.127262      0.140023
# min           0.025600          0.000037              0.000000      0.037100
# 25%           0.033706          0.138819              0.000000      0.131250
# 50%           0.039921          0.349257              0.000059      0.200491
# 75%           0.051906          0.551375              0.042338      0.306500
# max           0.222800          0.929400              0.810000      0.792500
#
#        avg_valence   avg_tempo  avg_duration_ms  avg_time_signature  \
# count   198.000000  198.000000       198.000000          198.000000
# mean      0.651029  122.007682    163953.439467            3.870858
# std       0.210569   22.567731     54450.192502            0.345537
# min       0.037800   72.323000     39573.333333            2.000000
# 25%       0.508000  106.955236    131779.937500            4.000000
# 50%       0.685333  122.441750    152778.000000            4.000000
# 75%       0.808900  134.802417    177206.687500            4.000000
# max       0.964000  194.277000    451426.666667            5.000000
#
#        avg_popularity  BB_peak_position  BB_weeks_on_chart  \
# count      198.000000              55.0               55.0
# mean        42.369923         22.563636           9.436364
# std          7.120020         21.631393             4.3066
# min         30.000000               2.0                1.0
# 25%         36.892857              11.0                7.0
# 50%         41.253846              13.0                9.0
# 75%         47.375000              34.5               11.0
# max         66.000000              96.0               26.0
#
#        RollingStonePosition  Top20_x  Next30_x  Bottom20_x  RobSegment  \
# count             26.000000     20.0      30.0        19.0  198.000000
# mean             206.846154      1.0       1.0         1.0    3.171717
# std              176.120343      0.0       0.0         0.0    0.961602
# min                8.000000      1.0       1.0         1.0    1.000000
# 25%               37.750000      1.0       1.0         1.0    3.000000
# 50%              147.000000      1.0       1.0         1.0    3.000000
# 75%              355.250000      1.0       1.0         1.0    4.000000
# max              500.000000      1.0       1.0         1.0    5.000000
#
#        Top20_y  Next30_y  Bottom20_y  LauraSegment  Top20_x  Next30_x  \
# count     20.0      30.0         9.0    198.000000     20.0      27.0
# mean       1.0       1.0         1.0      3.262626      1.0       1.0
# std        0.0       0.0         0.0      0.819630      0.0       0.0
# min        1.0       1.0         1.0      1.000000      1.0       1.0
# 25%        1.0       1.0         1.0      3.000000      1.0       1.0
# 50%        1.0       1.0         1.0      3.000000      1.0       1.0
# 75%        1.0       1.0         1.0      3.750000      1.0       1.0
# max        1.0       1.0         1.0      5.000000      1.0       1.0
#
#        Bottom20_x  EmilySegment  Top20_y  Next30_y  Bottom20_y  OliviaSegment  \
# count        18.0    198.000000     21.0      30.0         0.0     198.000000
# mean          1.0      3.156566      1.0       1.0         NaN       3.363636
# std           0.0      0.940209      0.0       0.0         NaN       0.667666
# min           1.0      1.000000      1.0       1.0         NaN       3.000000
# 25%           1.0      3.000000      1.0       1.0         NaN       3.000000
# 50%           1.0      3.000000      1.0       1.0         NaN       3.000000
# 75%           1.0      3.000000      1.0       1.0         NaN       4.000000
# max           1.0      5.000000      1.0       1.0         NaN       5.000000
#
#        Top20_x  Next30_x  Bottom20_x  BrianSegment  Top20_y  Next30_y  \
# count     20.0      28.0        16.0    198.000000     20.0      30.0
# mean       1.0       1.0         1.0      3.181818      1.0       1.0
# std        0.0       0.0         0.0      0.916445      0.0       0.0
# min        1.0       1.0         1.0      1.000000      1.0       1.0
# 25%        1.0       1.0         1.0      3.000000      1.0       1.0
# 50%        1.0       1.0         1.0      3.000000      1.0       1.0
# 75%        1.0       1.0         1.0      3.000000      1.0       1.0
# max        1.0       1.0         1.0      5.000000      1.0       1.0
#
#        Bottom20_y  JackieSegment        Year_y   Paul_Song   John_Song  \
# count         0.0     196.000000    176.000000  198.000000  198.000000
# mean          NaN       3.357143   2648.369318    0.348485    0.464646
# std           NaN       0.660225   2528.706096    0.477698    0.500013
# min           NaN       3.000000   1963.000000    0.000000    0.000000
# 25%           NaN       3.000000   1964.000000    0.000000    0.000000
# 50%           NaN       3.000000   1966.000000    0.000000    0.000000
# 75%           NaN       4.000000   1968.000000    1.000000    1.000000
# max           NaN       5.000000  11970.000000    1.000000    1.000000
#
#        George_Song  Ringo_Song       cover
# count   198.000000  198.000000  198.000000
# mean      0.131313    0.055556    0.101010
# std       0.338599    0.229642    0.302106
# min       0.000000    0.000000    0.000000
# 25%       0.000000    0.000000    0.000000
# 50%       0.000000    0.000000    0.000000
# 75%       0.000000    0.000000    0.000000
# max       1.000000    1.000000    1.000000

# %%
# 4. Checking unique values in columns
for column in df.columns:
    print("\nUnique values in column ", column, ": ", df[column].nunique())
# Out:
# Unique values in column  song :  198
#
# Unique values in column  core_catalogue_releases :  32
#
# Unique values in column  songwriters :  24
#
# Unique values in column  lead_vocals :  13
#
# Unique values in column  year :  11
#
# Unique values in column  SongKey :  198
#
# Unique values in column  first_release_date :  32
#
# Unique values in column  max_key :  12
#
# Unique values in column  mode :  2
#
# Unique values in column  avg_danceability :  195
#
# Unique values in column  avg_energy :  186
#
# Unique values in column  avg_loudness :  198
#
# Unique values in column  avg_speechiness :  184
#
# Unique values in column  avg_acousticness :  195
#
# Unique values in column  avg_instrumentalness :  138
#
# Unique values in column  avg_liveness :  191
#
# Unique values in column  avg_valence :  191
#
# Unique values in column  avg_tempo :  198
#
# Unique values in column  avg_duration_ms :  198
#
# Unique values in column  avg_time_signature :  24
#
# Unique values in column  Song_y :  198
#
# Unique values in column  lyrics :  198
#
# Unique values in column  avg_popularity :  132
#
# Unique values in column  BB_name :  55
#
# Unique values in column  BB_artist :  2
#
# Unique values in column  BB_debut_date :  41
#
# Unique values in column  BB_peak_position :  29
#
# Unique values in column  BB_peak_date :  47
#
# Unique values in column  BB_weeks_on_chart :  17
#
# Unique values in column  RollingStonePosition :  26
#
# Unique values in column  Top20_x :  Top20_x    1
# Top20_x    1
# Top20_x    1
# dtype: int64
#
# Unique values in column  Next30_x :  Next30_x    1
# Next30_x    1
# Next30_x    1
# dtype: int64
#
# Unique values in column  Bottom20_x :  Bottom20_x    1
# Bottom20_x    1
# Bottom20_x    1
# dtype: int64
#
# Unique values in column  RobSegment :  4
#
# Unique values in column  Top20_y :  Top20_y    1
# Top20_y    1
# Top20_y    1
# dtype: int64
#
# Unique values in column  Next30_y :  Next30_y    1
# Next30_y    1
# Next30_y    1
# dtype: int64
#
# Unique values in column  Bottom20_y :  Bottom20_y    1
# Bottom20_y    0
# Bottom20_y    0
# dtype: int64
#
# Unique values in column  LauraSegment :  4
#
# Unique values in column  Top20_x :  Top20_x    1
# Top20_x    1
# Top20_x    1
# dtype: int64
#
# Unique values in column  Next30_x :  Next30_x    1
# Next30_x    1
# Next30_x    1
# dtype: int64
#
# Unique values in column  Bottom20_x :  Bottom20_x    1
# Bottom20_x    1
# Bottom20_x    1
# dtype: int64
#
# Unique values in column  EmilySegment :  4
#
# Unique values in column  Top20_y :  Top20_y    1
# Top20_y    1
# Top20_y    1
# dtype: int64
#
# Unique values in column  Next30_y :  Next30_y    1
# Next30_y    1
# Next30_y    1
# dtype: int64
#
# Unique values in column  Bottom20_y :  Bottom20_y    1
# Bottom20_y    0
# Bottom20_y    0
# dtype: int64
#
# Unique values in column  OliviaSegment :  3
#
# Unique values in column  Top20_x :  Top20_x    1
# Top20_x    1
# Top20_x    1
# dtype: int64
#
# Unique values in column  Next30_x :  Next30_x    1
# Next30_x    1
# Next30_x    1
# dtype: int64
#
# Unique values in column  Bottom20_x :  Bottom20_x    1
# Bottom20_x    1
# Bottom20_x    1
# dtype: int64
#
# Unique values in column  BrianSegment :  4
#
# Unique values in column  Top20_y :  Top20_y    1
# Top20_y    1
# Top20_y    1
# dtype: int64
#
# Unique values in column  Next30_y :  Next30_y    1
# Next30_y    1
# Next30_y    1
# dtype: int64
#
# Unique values in column  Bottom20_y :  Bottom20_y    1
# Bottom20_y    0
# Bottom20_y    0
# dtype: int64
#
# Unique values in column  JackieSegment :  3
#
# Unique values in column  Canonical_album :  15
#
# Unique values in column  Year_y :  9
#
# Unique values in column  first_vocalist :  4
#
# Unique values in column  Paul_Song :  2
#
# Unique values in column  John_Song :  2
#
# Unique values in column  George_Song :  2
#
# Unique values in column  Ringo_Song :  2
#
# Unique values in column  cover :  2
#
# Unique values in column  Era :  3

# %%
# 5. Checking the datatypes
datatypes = df.dtypes
print("\nData types:\n", datatypes)
# Out:
# Data types:
#  song                               object
# core_catalogue_releases            object
# songwriters                        object
# lead_vocals                        object
# year                               object
# SongKey                            object
# first_release_date         datetime64[ns]
# max_key                           float64
# mode                              float64
# avg_danceability                  float64
# avg_energy                        float64
# avg_loudness                      float64
# avg_speechiness                   float64
# avg_acousticness                  float64
# avg_instrumentalness              float64
# avg_liveness                      float64
# avg_valence                       float64
# avg_tempo                         float64
# avg_duration_ms                   float64
# avg_time_signature                float64
# Song_y                             object
# lyrics                             object
# avg_popularity                    float64
# BB_name                            object
# BB_artist                          object
# BB_debut_date              datetime64[ns]
# BB_peak_position                    Int64
# BB_peak_date               datetime64[ns]
# BB_weeks_on_chart                   Int64
# RollingStonePosition              float64
# Top20_x                           float64
# Next30_x                          float64
# Bottom20_x                        float64
# RobSegment                        float64
# Top20_y                           float64
# Next30_y                          float64
# Bottom20_y                        float64
# LauraSegment                      float64
# Top20_x                           float64
# Next30_x                          float64
# Bottom20_x                        float64
# EmilySegment                      float64
# Top20_y                           float64
# Next30_y                          float64
# Bottom20_y                        float64
# OliviaSegment                     float64
# Top20_x                           float64
# Next30_x                          float64
# Bottom20_x                        float64
# BrianSegment                      float64
# Top20_y                           float64
# Next30_y                          float64
# Bottom20_y                        float64
# JackieSegment                     float64
# Canonical_album                    object
# Year_y                            float64
# first_vocalist                     object
# Paul_Song                           int32
# John_Song                           int32
# George_Song                         int32
# Ringo_Song                          int32
# cover                               int64
# Era                                object
# dtype: object

# %%
df['first_release_date'] = pd.to_datetime(df['first_release_date'])
df['LauraSegment'] = df['LauraSegment'].astype('int64')
df['RobSegment'] = df['RobSegment'].astype('int64')
df['EmilySegment'] = df['EmilySegment'].astype('int64')
df['OliviaSegment'] = df['OliviaSegment'].astype('int64')
df['BrianSegment'] = df['BrianSegment'].astype('int64')
df['JackieSegment'] = df['JackieSegment'].astype('int64')
df['year'] = df['year'].astype('int64')
# Out:
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# Cell In[13], line 7
#       5 df['OliviaSegment'] = df['OliviaSegment'].astype('int64')
#       6 df['BrianSegment'] = df['BrianSegment'].astype('int64')
# ----> 7 df['JackieSegment'] = df['JackieSegment'].astype('int64')
#       8 df['year'] = df['year'].astype('int64')
#
# File c:\Users\rob\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:6240, in NDFrame.astype(self, dtype, copy, errors)
#    6233     results = [
#    6234         self.iloc[:, i].astype(dtype, copy=copy)
#    6235         for i in range(len(self.columns))
#    6236     ]
#    6238 else:
#    6239     # else, only a single dtype is given
# -> 6240     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6241     return self._constructor(new_data).__finalize__(self, method="astype")
#    6243 # GH 33113: handle empty frame or series
#
# File c:\Users\rob\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\internals\managers.py:448, in BaseBlockManager.astype(self, dtype, copy, errors)
#     447 def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 448     return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#
# File c:\Users\rob\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\internals\managers.py:352, in BaseBlockManager.apply(self, f, align_keys, ignore_failures, **kwargs)
#     350         applied = b.apply(f, **kwargs)
#     351     else:
# --> 352         applied = getattr(b, f)(**kwargs)
#     353 except (TypeError, NotImplementedError):
#     354     if not ignore_failures:
#
# File c:\Users\rob\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\internals\blocks.py:526, in Block.astype(self, dtype, copy, errors)
#     508 """
#     509 Coerce to the new dtype.
#     510
#    (...)
#     522 Block
#     523 """
#     524 values = self.values
# --> 526 new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     528 new_values = maybe_coerce_values(new_values)
#     529 newb = self.make_block(new_values)
#
# File c:\Users\rob\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\dtypes\astype.py:299, in astype_array_safe(values, dtype, copy, errors)
#     296     return values.copy()
#     298 try:
# --> 299     new_values = astype_array(values, dtype, copy=copy)
#     300 except (ValueError, TypeError):
#     301     # e.g. astype_nansafe can fail on object-dtype of strings
#     302     #  trying to convert to float
#     303     if errors == "ignore":
#
# File c:\Users\rob\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\dtypes\astype.py:230, in astype_array(values, dtype, copy)
#     227     values = values.astype(dtype, copy=copy)
#     229 else:
# --> 230     values = astype_nansafe(values, dtype, copy=copy)
#     232 # in pandas we don't store numpy str dtypes, so convert to object
#     233 if isinstance(dtype, np.dtype) and issubclass(values.dtype.type, str):
#
# File c:\Users\rob\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\dtypes\astype.py:140, in astype_nansafe(arr, dtype, copy, skipna)
#     137     raise TypeError(f"cannot astype a timedelta from [{arr.dtype}] to [{dtype}]")
#     139 elif np.issubdtype(arr.dtype, np.floating) and is_integer_dtype(dtype):
# --> 140     return _astype_float_to_int_nansafe(arr, dtype, copy)
#     142 elif is_object_dtype(arr.dtype):
#     143
#     144     # if we have a datetime/timedelta array of objects
#     145     # then coerce to a proper dtype and recall astype_nansafe
#     147     if is_datetime64_dtype(dtype):
#
# File c:\Users\rob\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\dtypes\astype.py:182, in _astype_float_to_int_nansafe(values, dtype, copy)
#     178 """
#     179 astype with a check preventing converting NaN to an meaningless integer value.
#     180 """
#     181 if not np.isfinite(values).all():
# --> 182     raise IntCastingNaNError(
#     183         "Cannot convert non-finite values (NA or inf) to integer"
#     184     )
#     185 if dtype.kind == "u":
#     186     # GH#45151
#     187     if not (values >= 0).all():
#
# IntCastingNaNError: Cannot convert non-finite values (NA or inf) to integer

# %%
df.dtypes
# Out:
# song                               object
# core_catalogue_releases            object
# songwriters                        object
# lead_vocals                        object
# year                               object
# SongKey                            object
# first_release_date         datetime64[ns]
# max_key                           float64
# mode                              float64
# avg_danceability                  float64
# avg_energy                        float64
# avg_loudness                      float64
# avg_speechiness                   float64
# avg_acousticness                  float64
# avg_instrumentalness              float64
# avg_liveness                      float64
# avg_valence                       float64
# avg_tempo                         float64
# avg_duration_ms                   float64
# avg_time_signature                float64
# Song_y                             object
# lyrics                             object
# avg_popularity                    float64
# BB_name                            object
# BB_artist                          object
# BB_debut_date              datetime64[ns]
# BB_peak_position                    Int64
# BB_peak_date               datetime64[ns]
# BB_weeks_on_chart                   Int64
# RollingStonePosition              float64
# Top20_x                           float64
# Next30_x                          float64
# Bottom20_x                        float64
# RobSegment                          int64
# Top20_y                           float64
# Next30_y                          float64
# Bottom20_y                        float64
# LauraSegment                        int64
# Top20_x                           float64
# Next30_x                          float64
# Bottom20_x                        float64
# EmilySegment                        int64
# Top20_y                           float64
# Next30_y                          float64
# Bottom20_y                        float64
# OliviaSegment                       int64
# Top20_x                           float64
# Next30_x                          float64
# Bottom20_x                        float64
# BrianSegment                        int64
# Top20_y                           float64
# Next30_y                          float64
# Bottom20_y                        float64
# JackieSegment                     float64
# Canonical_album                    object
# Year_y                            float64
# first_vocalist                     object
# Paul_Song                           int32
# John_Song                           int32
# George_Song                         int32
# Ringo_Song                          int32
# cover                               int64
# Era                                object
# dtype: object

# %%
print(df.shape)
# Out:
# (198, 63)

# %%
print(df.head(10).to_string())
# Out:
#                      song core_catalogue_releases                     songwriters              lead_vocals  year             SongKey first_release_date  max_key  mode  avg_danceability  avg_energy  avg_loudness  avg_speechiness  avg_acousticness  avg_instrumentalness  avg_liveness  avg_valence   avg_tempo  avg_duration_ms  avg_time_signature                  Song_y                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              lyrics  avg_popularity               BB_name    BB_artist BB_debut_date  BB_peak_position BB_peak_date  BB_weeks_on_chart  RollingStonePosition  Top20_x  Next30_x  Bottom20_x  RobSegment  Top20_y  Next30_y  Bottom20_y  LauraSegment  Top20_x  Next30_x  Bottom20_x  EmilySegment  Top20_y  Next30_y  Bottom20_y  OliviaSegment  Top20_x  Next30_x  Bottom20_x  BrianSegment  Top20_y  Next30_y  Bottom20_y  JackieSegment       Canonical_album   Year_y first_vocalist  Paul_Song  John_Song  George_Song  Ringo_Song  cover                    Era
# 0     Across the Universe  Let It Be Past Masters                Lennon McCartney                   Lennon  1969   acrosstheuniverse         1970-05-08      2.0   1.0          0.347600    0.409000      -10.6498         0.028000          0.518200              0.000022      0.239420     0.789400  140.437800    223713.600000            4.000000     Across the universe                                                                                                                                           Words are flowing out like endless rain into a paper cup, They slither while they pass, they slip away across the universe Pools of sorrow, waves of joy are drifting through my open mind, Possessing and caressing me. Jai guru de va om Nothing's gonna change my world, Nothing's gonna change my world.  Images of broken light which dance before me like a million eyes, That call me on and on across the universe, Thoughts meander like a restless wind inside a letter box they Tumble blindly as they make their way Across the universe Jai guru de va om Nothing's gonna change my world, Nothing's gonna change my world.  Sounds of laughter shades of earth are ringing Through my open views inviting and inciting me Limitless undying love which shines around me like a Million suns, it calls me on and on Across the universe Jai guru de va om Nothing's gonna change my world, Nothing's gonna change my world.        41.875000                   NaN          NaN           NaT              <NA>          NaT               <NA>                   NaN